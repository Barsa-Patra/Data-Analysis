# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="darkgrid")

# %%
pd.set_option("display.max_columns",None)

# %%
df=pd.read_csv("Shark Tank India Dataset.csv")
df
# Out:
#      episode_number  pitch_number           brand_name  \
# 0                 1             1  BluePine Industries
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# 1    Renting e-bike for mobility in private spaces     1                40.0
# ...

# %%
df.describe()
# Out:
#        episode_number  pitch_number        deal  pitcher_ask_amount  \
# count      117.000000    117.000000  117.000000          117.000000
# mean        18.735043     59.000000    0.555556          319.854709
# std         10.070778     33.919021    0.499041         2767.842777
# min          1.000000      1.000000    0.000000            0.001010
# 25%         10.000000     30.000000    0.000000           45.000000
# 50%         19.000000     59.000000    1.000000           50.000000
# 75%         27.000000     88.000000    1.000000           80.000000
# max         35.000000    117.000000    1.000000        30000.000000
#
#        ask_equity  ask_valuation  deal_amount  deal_equity  deal_valuation  \
# count  117.000000     117.000000   117.000000   117.000000      117.000000
# mean     5.188034    3852.462479    31.982915     8.963504      467.104872
# std      3.892121   11931.601957    36.687391    13.106769      919.988864
# ...

# %%
df.head()
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# 4                       Brain Development Course     0                50.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  deal_valuation  \
# 0         5.0        1000.00         75.0        16.00          468.75
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## How Many deal done in the whole season.

# %%
done=df[df["deal"]==1].count()[0]
print("Succesfull Deal.....",done)
not_done=df[df["deal"]==0].count()[0]
print("Rejected Deal.....",not_done)
# Out:
# Succesfull Deal..... 65
# Rejected Deal..... 52

# %%
df["deal"].value_counts()
# Out:
# 1    65
# 0    52
# Name: deal, dtype: int64

# %%
df["deal"].value_counts().plot(autopct="%.2f%%",kind="pie",label="Deal");

# %%
best_ep=df.groupby(["episode_number"])["deal"].sum().sort_values(ascending=False).reset_index()
best_ep
# Out:
#     episode_number  deal
# 0                1     3
# 1               15     3
# 2               21     3
# 3               33     3
# 4                8     3
# 5               10     3
# 6               17     3
# 7               16     3
# 8               13     3
# 9               25     2
# 10              24     2
# 11              28     2
# 12              20     2
# 13              26     2
# 14              27     2
# 15              12     2
# 16              11     2
# 17               9     2
# 18               6     2
# 19               4     2
# 20               3     2
# 21              31     1
# 22              30     1
# 23              29     1
# 24              34     1
# 25              32     1
# 26              18     1
# 27              23     1
# 28              22     1
# 29              19     1
# 30               2     1
# 31              14     1
# 32               7     1
# 33               5     1
# 34              35     1

# %%
sns.catplot(x="deal",y="episode_number",data=df)

# %% [markdown]
# Most Expensive Deal Eposide

# %%
df
# Out:
#      episode_number  pitch_number           brand_name  \
# 0                 1             1  BluePine Industries
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# 1    Renting e-bike for mobility in private spaces     1                40.0
# ...

# %%
df.groupby(df["episode_number"])["deal_amount"].sum().sort_values(ascending=False).reset_index()
# Out:
#     episode_number  deal_amount
# 0               17    280.00000
# 1               13    255.00000
# 2               16    170.00000
# 3               21    160.00000
# 4               28    150.00000
# 5               25    150.00000
# 6                6    150.00000
# 7               20    140.00000
# 8                1    140.00000
# 9                8    136.00000
# 10              15    125.00005
# 11               4    125.00000
# 12              12    115.00000
# 13              26    115.00000
# 14              33    110.00000
# 15              27    100.00101
# 16               9    100.00000
# 17              14    100.00000
# 18               7    100.00000
# 19               5    100.00000
# 20               3     95.00000
# 21              10     85.00000
# 22              11     80.00000
# 23              30     80.00000
# 24              29     75.00000
# 25              31     75.00000
# 26               2     70.00000
# 27              24     60.00000
# ...

# %%
deal=df.groupby(df["brand_name"])["deal_amount"].sum().sort_values(ascending=False).reset_index()
deal
# Out:
#             brand_name  deal_amount
# 0        Aas Vidyalaya        150.0
# 1                Annie        105.0
# 2    The Renal Project        100.0
# 3           Get a Whey        100.0
# 4      The Yarn Bazaar        100.0
# ..                 ...          ...
# 112          KetoIndia          0.0
# 113    Kabira Handmade          0.0
# 114   Julaa Automation          0.0
# 115       JhaJi Achaar          0.0
# 116              Woloo          0.0
#
# [117 rows x 2 columns]

# %%
plt.figure(figsize=(40,40))
sns.barplot(df["brand_name"],df["deal_amount"],data=df)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.title("Maximum Sharks in")
plt.bar(df["episode_number"],df["total_sharks_invested"])
# Out:
# <BarContainer object of 117 artists>

# %%
# No Bargain Deal

# %%
df[df["ask_valuation"]==df["deal_valuation"]]
# Out:
#     episode_number  pitch_number    brand_name                 idea  deal  \
# 21               8            22  Beyond Snack  Kerala Banana Chips     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 21                50.0         2.5         2000.0         50.0          2.5
#
#     deal_valuation  ashneer_present  anupam_present  aman_present  \
# 21          2000.0                1               1             1
#
#     namita_present  vineeta_present  peyush_present  ghazal_present  \
# 21               1                0               1               0
#
#     ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 21             1            0          1            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 21            0            0                      2              25.0
#
#     equity_per_shark
# 21              1.25

# %% [markdown]
# # No of Shark invested with respected to Business

# %%
plt.figure(figsize=(20,20))
sns.countplot(x=df["total_sharks_invested"])
plt.title("Number of shark invested",fontsize=15)
plt.show()

# %%
def sharks(data):
    list= ['anupam_deal','aman_deal','namita_deal','vineeta_deal','peyush_deal','ghazal_deal','ashneer_deal']
    for i in list:
        deal = data[['amount_per_shark','equity_per_shark']][data[i]==1]
        print("\n{} deals with {}".format(len(deal),i[:-5]))
        print(deal)

# %%
ash_grover=df[df["ashneer_deal"]==1]

# %%
sharks(ash_grover)
# Out:
# 8 deals with anupam
#      amount_per_shark  equity_per_shark
# 15               20.0          3.000000
# 38               25.0          2.500000
# 45               25.0          1.750000
# 49               10.0          5.000000
# 63               20.0          2.000000
# 67               20.0          1.333333
# 108              20.0          3.333333
# 114              10.0          7.500000
#
# 11 deals with aman
#      amount_per_shark  equity_per_shark
# 0           25.000000          5.333333
# 15          20.000000          3.000000
# 18          50.000000          2.000000
# 21          25.000000          1.250000
# 29          10.000000          1.000000
# 38          25.000000          2.500000
# 49          10.000000          5.000000
# 58          15.000000          2.500000
# 63          20.000000          2.000000
# 64          33.333333          5.000000
# 114         10.000000          7.500000
#
# 6 deals with namita
#      amount_per_shark  equity_per_shark
# ...

# %%
df
# Out:
#      episode_number  pitch_number           brand_name  \
# 0                 1             1  BluePine Industries
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# 1    Renting e-bike for mobility in private spaces     1                40.0
# ...

# %%
teamup=df[df["total_sharks_invested"]>1]
plt.figure(figsize=(7,7))
plt.hist(teamup.total_sharks_invested)
plt.title("visualization of number of sharks teamedup")
plt.xlabel("Number of sharks")
plt.ylabel("Number of investments");

# %%
for i in df:
    print(i)
# Out:
# episode_number
# pitch_number
# brand_name
# idea
# deal
# pitcher_ask_amount
# ask_equity
# ask_valuation
# deal_amount
# deal_equity
# deal_valuation
# ashneer_present
# anupam_present
# aman_present
# namita_present
# vineeta_present
# peyush_present
# ghazal_present
# ashneer_deal
# anupam_deal
# aman_deal
# namita_deal
# vineeta_deal
# peyush_deal
# ghazal_deal
# total_sharks_invested
# amount_per_shark
# equity_per_shark

# %%
a=df[df["ashneer_deal"]==1]
aa=list(a.amount_per_shark)
t=0
for i in aa:
    t=t+i
print(t)
# Out:
# 494.33333333

# %%
a["amount_per_shark"].sum()
# Out:
# 494.33333333

# %%
a.groupby(a["ashneer_deal"])["amount_per_shark"].sum()
# Out:
# ashneer_deal
# 1    494.333333
# Name: amount_per_shark, dtype: float64

# %%
#Which Shark Invested in More Companies

# %%
list=["ashneer_deal","anupam_deal","aman_deal","namita_deal","vineeta_deal","peyush_deal","ghazal_deal"]
for i in list:
    deal=df[i].sum()
    print(i,"deal with",deal,"Companies")
# Out:
# ashneer_deal deal with 21 Companies
# anupam_deal deal with 24 Companies
# aman_deal deal with 28 Companies
# namita_deal deal with 22 Companies
# vineeta_deal deal with 15 Companies
# peyush_deal deal with 27 Companies
# ghazal_deal deal with 7 Companies

# %%
list=["ashneer_present","anupam_present","aman_present","namita_present","vineeta_present","peyush_present","ghazal_present"]
for i in list:
    pres=df[i].sum()
    print(i,"present with",pres,"Companies")
# Out:
# ashneer_present present with 98 Companies
# anupam_present present with 117 Companies
# aman_present present with 98 Companies
# namita_present present with 106 Companies
# vineeta_present present with 66 Companies
# peyush_present present with 88 Companies
# ghazal_present present with 26 Companies

# %%
fig,ax=plt.subplots(figsize=(30,30))
sns.barplot(data=df,y="ask_valuation",x="amount_per_shark",ci=None)
# Out:
# <AxesSubplot:xlabel='amount_per_shark', ylabel='ask_valuation'>
